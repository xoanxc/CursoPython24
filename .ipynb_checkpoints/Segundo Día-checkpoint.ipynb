# %% [markdown]
# # Listas

# %%
semana=["Lunes", "Martes", "Miercoles", "Jueves", "Viernes", "Sabado", "Domingo"]

# %%
semana[0]
# Out:
# 'Lunes'

# %%
semana[0:5]
# Out:
# ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes']

# %%
finde=semana[5:]

# %%
finde
# Out:
# ['Sabado', 'Domingo']

# %%
len(finde)
# Out:
# 2

# %%
finde.append("Lunes")

# %%
finde
# Out:
# ['Sabado', 'Domingo', 'Lunes']

# %%
print(semana)
# Out:
# ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']

# %%
for dia in semana:
    print(dia)
# Out:
# Lunes
# Martes
# Miercoles
# Jueves
# Viernes
# Sabado
# Domingo

# %%
for indice in range(7):
    if indice%2 == 0:
        print(semana[indice])
# Out:
# Lunes
# Miercoles
# Viernes
# Domingo

# %% [markdown]
# # Tupla

# %%
tupla = ("Lunes", "Martes")

# %%
tupla[0]
# Out:
# 'Lunes'

# %%
precios=[
    ("Manzana", 2),
    ("Naranjas", 3)
]

# %%
display(precios)
# Out:
# [('Manzana', 2), ('Naranjas', 3)]

# %%
precios[0]
# Out:
# ('Manzana', 2)

# %%
precios[0][0]
# Out:
# 'Manzana'

# %%
precios[1]
# Out:
# ('Naranjas', 3)

# %%
producto,precio = precios[1]

# %% [raw]
# producto

# %%
precio
# Out:
# 3

# %% [markdown]
# # Trabajar con Imagenes

# %%
# !pip install pillow

# %%
from PIL import Image

# %%
frierenIM= Image.open("Frieren.png")

# %%
frierenIM
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x1051>

# %%
frierenIM.size
# Out:
# (386, 1051)

# %%
frierenPeque = frierenIM.resize((38,101))

# %%
frierenPeque
# Out:
# <PIL.Image.Image image mode=RGBA size=38x101>

# %%
# Adios PC
frierenGOOD = frierenIM.resize((99999,99999))

# %%
frierenGOOD
